# %% [markdown]
# # Run ML Insights Using Config File

# %% [markdown]
# # Use Case
#
# This Notebook shows the ML Insights Low code option to define and customise all of its core features like data scheme , data ingestion, data transformation, metric calculation and post processing of metric output using json based configuration .
#
# ### About Dataset
# The Iris flower data set or Fisher's Iris data set is a multivariate data set . The data set consists of 50 samples from each of three species of Iris (Iris setosa, Iris virginica and Iris versicolor). Four features were measured from each sample: the length and the width of the sepals and petals, in centimeters.
#
# Dataset source : https://archive.ics.uci.edu/dataset/53/iris

# %% [markdown]
# # Install ML Observability Insights Library SDK
#
# - Prerequisites
#     - Linux/Mac (Intel CPU)
#     - Python 3.8 and 3.9 only
#
#
# - Installation
#     - ML Insights is made available as a Python package (via Artifactory) which can be installed using pip install as shown below. Depending on the execution engine on which to do the run, one can use scoped package. For eg: if we want to run on dask, use oracle-ml-insights[dask], for spark use oracle-ml-insights[spark], for native use oracle-ml-insights. One can install all the dependencies as use oracle-ml-insights[all]
#
#       !pip install oracle-ml-insights
#
#
# Refer : [Installation and Setup](https://docs.oracle.com/en-us/iaas/tools/ml-insights-docs/latest/ml-insights-documentation/html/user_guide/tutorials/install.html)

# %% [markdown]
# This example notebook showcases how to use Insights config reader to run the evaluation based on monitor config.  Sample monitor config JSON and sample data are available under `monitor_configs/monitor_config.json` and `input_data/iris-dataset` respectively

# %%
# !python3 -m pip install oracle-ml-insights

# %% [markdown]
# # 1 ML Insights Imports

# %%
import pandas as pd

from mlm_insights.builder.insights_builder import InsightsBuilder
from mlm_insights.config_reader.insights_config_reader import InsightsConfigReader

import json

# %% [markdown]
# # 2 What is Json based Configuration
#
# ML Insights provides low code option to define and customise all of its core features like data scheme , data ingestion, data transformation, metric calculation and post processing of metric output using json based configuration .
#
# Refer : [ML Insights Config File Documentation](https://docs.oracle.com/en-us/iaas/tools/ml-insights-docs/latest/ml-insights-documentation/html/user_guide/tutorials/config_reader.html)

# %% [markdown]
# # 3 Compute the profile
#
# Initialize the Insights builder by specifying the location of the monitor config JSON using the Insights config reader.
#
# The run() method is responsible to run the internal workflow. It also handles the life cycle of each component passed, which includes creation (if required), invoking interface functions, destroying etc . Additionally, runner also handles some more advanced operations like thread pooling, compute engine abstraction etc.

# %%
insights_builder = InsightsConfigReader(config_location="monitor_configs/monitor_config.json").get_builder()
run_result = insights_builder.build().run()
profile = run_result.profile

# %% [markdown]
# # 4 Result

# %% [markdown]
# ## 4.1 Visualize the Profile in tabular format

# %%
profile.to_pandas()
# Out:
#                    Skewness  StandardDeviation  Min  IsConstantFeature  IQR  \
# sepal length (cm)  0.311753           0.825301  4.3              False  1.3
# sepal width (cm)   0.315767           0.434411  2.0              False  0.5
# petal length (cm) -0.272128           1.759404  1.0              False  3.5
# petal width (cm)  -0.101934           0.759693  0.1              False  1.5
#
#                          Mode  Range  TypeMetric.string_type_count  \
# sepal length (cm)       [5.0]    3.6                             0
# sepal width (cm)        [3.0]    2.4                             0
# petal length (cm)  [1.4, 1.5]    5.9                             0
# petal width (cm)        [0.2]    2.4                             0
#
#                    TypeMetric.integral_type_count  \
# sepal length (cm)                               0
# sepal width (cm)                                0
# petal length (cm)                               0
# petal width (cm)                                0
#
#                    TypeMetric.fractional_type_count  ...  \
# sepal length (cm)                               600  ...
# sepal width (cm)                                600  ...
# petal length (cm)                               600  ...
# petal width (cm)                                600  ...
#
#                    Count.missing_count_percentage  Max  DistinctCount     Sum  \
# sepal length (cm)                             0.0  7.9             35  3506.0
# sepal width (cm)                              0.0  4.4             23  1834.4
# petal length (cm)                             0.0  6.9             43  2254.8
# petal width (cm)                              0.0  2.5             22   719.6
#
#                    IsQuasiConstantFeature  Quartiles.q1  Quartiles.q2  \
# sepal length (cm)                   False           5.1           5.8
# sepal width (cm)                    False           2.8           3.0
# petal length (cm)                   False           1.6           4.3
# petal width (cm)                    False           0.3           1.3
#
#                    Quartiles.q3      Mean  Kurtosis
# sepal length (cm)           6.4  5.843333 -0.573568
# sepal width (cm)            3.3  3.057333  0.180976
# petal length (cm)           5.1  3.758000 -1.395536
# petal width (cm)            1.8  1.199333 -1.336067
#
# [4 rows x 26 columns]

# %% [markdown]
# ## 4.2 Visualize the Profile in JSON format

# %%
profile_json = profile.to_json()
dataset_metrics = profile_json
print(json.dumps(dataset_metrics,sort_keys=True, indent=4))
# Out:
# {
#     "dataset_metrics": {},
#     "feature_metrics": {
#         "petal length (cm)": {
#             "Count": {
#                 "metadata": {},
#                 "metric_data": [
#                     600.0,
#                     0.0,
#                     0.0
#                 ],
#                 "metric_description": "Feature metric that returns total count, missing count and missing count percentage",
#                 "metric_name": "Count",
#                 "variable_count": 3,
#                 "variable_dimensions": [
#                     0,
#                     0,
#                     0
#                 ],
#                 "variable_dtypes": [
#                     "INTEGER",
#                     "INTEGER",
#                     "FLOAT"
#                 ],
#                 "variable_names": [
#                     "total_count",
#                     "missing_count",
#                     "missing_count_percentage"
#                 ],
#                 "variable_types": [
#                     "CONTINUOUS",
#                     "CONTINUOUS",
#                     "CONTINUOUS"
#                 ]
#             },
#             "DistinctCount": {
#                 "metadata": {},
#                 "metric_data": [
#                     43
#                 ],
#                 "metric_description": "Approximate Distinct Count",
#                 "metric_name": "DistinctCount",
#                 "variable_count": 1,
#                 "variable_dimensions": [
#                     0
#                 ],
#                 "variable_dtypes": [
#                     "INTEGER"
#                 ],
#                 "variable_names": [
#                     "distinct_count"
#                 ],
#                 "variable_types": [
#                     "CONTINUOUS"
#                 ]
#             },
#             "DuplicateCount": {
#                 "metadata": {},
#                 "metric_data": [
#                     557,
#                     92.83333333333333
#                 ],
#                 "metric_description": "Feature Metric to compute duplicate count and duplicate count percentage",
#                 "metric_name": "DuplicateCount",
#                 "variable_count": 2,
#                 "variable_dimensions": [
#                     0,
#                     0
#                 ],
#                 "variable_dtypes": [
#                     "INTEGER",
#                     "FLOAT"
#                 ],
#                 "variable_names": [
#                     "count",
#                     "percentage"
#                 ],
#                 "variable_types": [
#                     "CONTINUOUS",
#                     "CONTINUOUS"
#                 ]
#             },
#             "IQR": {
#                 "metadata": {},
#                 "metric_data": [
#                     3.4999999999999996
#                 ],
#                 "metric_description": "Compute the interquartile range of the data. Interquartile range (IQR) is the difference between the 75th and 25th percentile of the data. It is a measure of the dispersion similar to standard deviation or variance, but is much more robust against outliers",
#                 "metric_name": "IQR",
#                 "variable_count": 1,
#                 "variable_dimensions": [
#                     0
#                 ],
#                 "variable_dtypes": [
#                     "FLOAT"
#                 ],
#                 "variable_names": [
#                     "iqr"
#                 ],
#                 "variable_types": [
#                     "CONTINUOUS"
#                 ]
#             },
#             "IsConstantFeature": {
#                 "metadata": {},
#                 "metric_data": [
#                     false
#                 ],
#                 "metric_description": "Feature Metric to compute if all values are same",
#                 "metric_name": "IsConstantFeature",
#                 "variable_count": 1,
#                 "variable_dimensions": [
#                     0
#                 ],
#                 "variable_dtypes": [
#                     "BOOLEAN"
#                 ],
#                 "variable_names": [
#                     "is_constant"
#                 ],
#                 "variable_types": [
#                     "BINARY"
#                 ]
#             },
#             "IsQuasiConstantFeature": {
#                 "metadata": {},
#                 "metric_data": [
#                     false
#                 ],
#                 "metric_description": "Feature Metric to compute if all values are almost same",
#                 "metric_name": "IsQuasiConstantFeature",
#                 "variable_count": 1,
#                 "variable_dimensions": [
#                     0
#                 ],
#                 "variable_dtypes": [
#                     "BOOLEAN"
#                 ],
#                 "variable_names": [
#                     "is_quasi_constant"
#                 ],
#                 "variable_types": [
#                     "BINARY"
#                 ]
#             },
#             "Kurtosis": {
#                 "metadata": {},
#                 "metric_data": [
#                     -1.3955358863990055
#                 ],
#                 "metric_description": "Feature Metric to compute Kurtosis",
#                 "metric_name": "Kurtosis",
#                 "variable_count": 1,
#                 "variable_dimensions": [
#                     0
#                 ],
#                 "variable_dtypes": [
#                     "FLOAT"
#                 ],
#                 "variable_names": [
#                     "kurtosis"
#                 ],
#                 "variable_types": [
#                     "CONTINUOUS"
#                 ]
#             },
#             "Max": {
#                 "metadata": {},
#                 "metric_data": [
#                     6.9
#                 ],
#                 "metric_description": "Feature Metric to compute maximum value",
#                 "metric_name": "Max",
#                 "variable_count": 1,
#                 "variable_dimensions": [
#                     0
#                 ],
#                 "variable_dtypes": [
#                     "FLOAT"
#                 ],
#                 "variable_names": [
#                     "max"
#                 ],
#                 "variable_types": [
#                     "CONTINUOUS"
#                 ]
#             },
#             "Mean": {
#                 "metadata": {},
#                 "metric_data": [
#                     3.7580000000000005
#                 ],
#                 "metric_description": "Feature Metric to compute mean",
#                 "metric_name": "Mean",
#                 "variable_count": 1,
#                 "variable_dimensions": [
#                     0
#                 ],
#                 "variable_dtypes": [
#                     "FLOAT"
#                 ],
#                 "variable_names": [
#                     "mean"
#                 ],
#                 "variable_types": [
#                     "CONTINUOUS"
#                 ]
#             },
#             "Min": {
#                 "metadata": {},
#                 "metric_data": [
#                     1.0
#                 ],
#                 "metric_description": "Feature Metric to compute minimum value",
#                 "metric_name": "Min",
#                 "variable_count": 1,
#                 "variable_dimensions": [
#                     0
#                 ],
#                 "variable_dtypes": [
#                     "FLOAT"
#                 ],
#                 "variable_names": [
#                     "min"
#                 ],
#                 "variable_types": [
#                     "CONTINUOUS"
#                 ]
#             },
#             "Mode": {
#                 "metadata": {},
#                 "metric_data": [
#                     [
#                         "1.4",
#                         "1.5"
#                     ]
#                 ],
#                 "metric_description": "Mode",
#                 "metric_name": "Mode",
#                 "variable_count": 1,
#                 "variable_dimensions": [
#                     1
#                 ],
#                 "variable_dtypes": [
#                     "STRING"
#                 ],
#                 "variable_names": [
#                     "mode"
#                 ],
#                 "variable_types": [
#                     "NOMINAL"
#                 ]
#             },
#             "Quartiles": {
#                 "metadata": {},
#                 "metric_data": [
#                     1.6,
#                     4.3,
#                     5.1
#                 ],
#                 "metric_description": "Feature Metric to compute Quartiles (Q1, Q2, Q3)",
#                 "metric_name": "Quartiles",
#                 "variable_count": 3,
#                 "variable_dimensions": [
#                     0,
#                     0,
#                     0
#                 ],
#                 "variable_dtypes": [
#                     "FLOAT",
#                     "FLOAT",
#                     "FLOAT"
#                 ],
#                 "variable_names": [
#                     "q1",
#                     "q2",
#                     "q3"
#                 ],
#                 "variable_types": [
#                     "CONTINUOUS",
#                     "CONTINUOUS",
#                     "CONTINUOUS"
#                 ]
#             },
#             "Range": {
#                 "metadata": {},
#                 "metric_data": [
#                     5.9
#                 ],
#                 "metric_description": "Feature Metric to compute range value",
#                 "metric_name": "Range",
#                 "variable_count": 1,
#                 "variable_dimensions": [
#                     0
#                 ],
#                 "variable_dtypes": [
#                     "FLOAT"
#                 ],
#                 "variable_names": [
#                     "range"
#                 ],
#                 "variable_types": [
#                     "CONTINUOUS"
#                 ]
#             },
#             "Skewness": {
#                 "metadata": {},
#                 "metric_data": [
#                     -0.2721276664567213
#                 ],
#                 "metric_description": "Feature Metric to compute Skewness",
#                 "metric_name": "Skewness",
#                 "variable_count": 1,
#                 "variable_dimensions": [
#                     0
#                 ],
#                 "variable_dtypes": [
#                     "FLOAT"
#                 ],
#                 "variable_names": [
#                     "skewness"
#                 ],
#                 "variable_types": [
#                     "CONTINUOUS"
#                 ]
#             },
#             "StandardDeviation": {
#                 "metadata": {},
#                 "metric_data": [
#                     1.759404065775303
#                 ],
#                 "metric_description": "Feature Metric to compute Standard Deviation",
#                 "metric_name": "StandardDeviation",
#                 "variable_count": 1,
#                 "variable_dimensions": [
#                     0
#                 ],
#                 "variable_dtypes": [
#                     "FLOAT"
#                 ],
#                 "variable_names": [
#                     "standard_deviation"
#                 ],
#                 "variable_types": [
#                     "CONTINUOUS"
#                 ]
#             },
#             "Sum": {
#                 "metadata": {},
#                 "metric_data": [
#                     2254.8
#                 ],
#                 "metric_description": "",
#                 "metric_name": "Sum",
#                 "variable_count": 1,
#                 "variable_dimensions": [
#                     0
#                 ],
#                 "variable_dtypes": [
#                     "FLOAT"
#                 ],
#                 "variable_names": [
#                     "sum"
#                 ],
#                 "variable_types": [
#                     "CONTINUOUS"
#                 ]
#             },
#             "TypeMetric": {
#                 "metadata": {},
#                 "metric_data": [
#                     0,
#                     0,
#                     600,
#                     0
#                 ],
#                 "metric_description": "Feature Metric to compute count of data types for feature values",
#                 "metric_name": "TypeMetric",
#                 "variable_count": 4,
#                 "variable_dimensions": [
#                     0,
#                     0,
#                     0,
#                     0
#                 ],
#                 "variable_dtypes": [
#                     "INTEGER",
#                     "INTEGER",
#                     "INTEGER",
#                     "INTEGER"
#                 ],
#                 "variable_names": [
#                     "string_type_count",
#                     "integral_type_count",
#                     "fractional_type_count",
#                     "boolean_type_count"
#                 ],
#                 "variable_types": [
#                     "DISCRETE",
#                     "DISCRETE",
#                     "DISCRETE",
#                     "DISCRETE"
#                 ]
#             },
#             "Variance": {
#                 "metadata": {},
#                 "metric_data": [
#                     3.0955026666666665
#                 ],
#                 "metric_description": "Feature Metric to compute Variance",
#                 "metric_name": "Variance",
#                 "variable_count": 1,
#                 "variable_dimensions": [
#                     0
#                 ],
#                 "variable_dtypes": [
#                     "FLOAT"
#                 ],
#                 "variable_names": [
#                     "variance"
#                 ],
#                 "variable_types": [
#                     "CONTINUOUS"
#                 ]
#             }
#         },
#         "petal width (cm)": {
#             "Count": {
#                 "metadata": {},
#                 "metric_data": [
#                     600.0,
#                     0.0,
#                     0.0
#                 ],
#                 "metric_description": "Feature metric that returns total count, missing count and missing count percentage",
#                 "metric_name": "Count",
#                 "variable_count": 3,
#                 "variable_dimensions": [
#                     0,
#                     0,
#                     0
#                 ],
#                 "variable_dtypes": [
#                     "INTEGER",
#                     "INTEGER",
#                     "FLOAT"
#                 ],
#                 "variable_names": [
#                     "total_count",
#                     "missing_count",
#                     "missing_count_percentage"
#                 ],
#                 "variable_types": [
#                     "CONTINUOUS",
#                     "CONTINUOUS",
#                     "CONTINUOUS"
#                 ]
#             },
#             "DistinctCount": {
#                 "metadata": {},
#                 "metric_data": [
#                     22
#                 ],
#                 "metric_description": "Approximate Distinct Count",
#                 "metric_name": "DistinctCount",
#                 "variable_count": 1,
#                 "variable_dimensions": [
#                     0
#                 ],
#                 "variable_dtypes": [
#                     "INTEGER"
#                 ],
#                 "variable_names": [
#                     "distinct_count"
#                 ],
#                 "variable_types": [
#                     "CONTINUOUS"
#                 ]
#             },
#             "DuplicateCount": {
#                 "metadata": {},
#                 "metric_data": [
#                     578,
#                     96.33333333333334
#                 ],
#                 "metric_description": "Feature Metric to compute duplicate count and duplicate count percentage",
#                 "metric_name": "DuplicateCount",
#                 "variable_count": 2,
#                 "variable_dimensions": [
#                     0,
#                     0
#                 ],
#                 "variable_dtypes": [
#                     "INTEGER",
#                     "FLOAT"
#                 ],
#                 "variable_names": [
#                     "count",
#                     "percentage"
#                 ],
#                 "variable_types": [
#                     "CONTINUOUS",
#                     "CONTINUOUS"
#                 ]
#             },
#             "IQR": {
#                 "metadata": {},
#                 "metric_data": [
#                     1.5
#                 ],
#                 "metric_description": "Compute the interquartile range of the data. Interquartile range (IQR) is the difference between the 75th and 25th percentile of the data. It is a measure of the dispersion similar to standard deviation or variance, but is much more robust against outliers",
#                 "metric_name": "IQR",
#                 "variable_count": 1,
#                 "variable_dimensions": [
#                     0
#                 ],
#                 "variable_dtypes": [
#                     "FLOAT"
#                 ],
#                 "variable_names": [
#                     "iqr"
#                 ],
#                 "variable_types": [
#                     "CONTINUOUS"
#                 ]
#             },
#             "IsConstantFeature": {
#                 "metadata": {},
#                 "metric_data": [
#                     false
#                 ],
#                 "metric_description": "Feature Metric to compute if all values are same",
#                 "metric_name": "IsConstantFeature",
#                 "variable_count": 1,
#                 "variable_dimensions": [
#                     0
#                 ],
#                 "variable_dtypes": [
#                     "BOOLEAN"
#                 ],
#                 "variable_names": [
#                     "is_constant"
#                 ],
#                 "variable_types": [
#                     "BINARY"
#                 ]
#             },
#             "IsQuasiConstantFeature": {
#                 "metadata": {},
#                 "metric_data": [
#                     false
#                 ],
#                 "metric_description": "Feature Metric to compute if all values are almost same",
#                 "metric_name": "IsQuasiConstantFeature",
#                 "variable_count": 1,
#                 "variable_dimensions": [
#                     0
#                 ],
#                 "variable_dtypes": [
#                     "BOOLEAN"
#                 ],
#                 "variable_names": [
#                     "is_quasi_constant"
#                 ],
#                 "variable_types": [
#                     "BINARY"
#                 ]
#             },
#             "Kurtosis": {
#                 "metadata": {},
#                 "metric_data": [
#                     -1.3360674052315529
#                 ],
#                 "metric_description": "Feature Metric to compute Kurtosis",
#                 "metric_name": "Kurtosis",
#                 "variable_count": 1,
#                 "variable_dimensions": [
#                     0
#                 ],
#                 "variable_dtypes": [
#                     "FLOAT"
#                 ],
#                 "variable_names": [
#                     "kurtosis"
#                 ],
#                 "variable_types": [
#                     "CONTINUOUS"
#                 ]
#             },
#             "Max": {
#                 "metadata": {},
#                 "metric_data": [
#                     2.5
#                 ],
#                 "metric_description": "Feature Metric to compute maximum value",
#                 "metric_name": "Max",
#                 "variable_count": 1,
#                 "variable_dimensions": [
#                     0
#                 ],
#                 "variable_dtypes": [
#                     "FLOAT"
#                 ],
#                 "variable_names": [
#                     "max"
#                 ],
#                 "variable_types": [
#                     "CONTINUOUS"
#                 ]
#             },
#             "Mean": {
#                 "metadata": {},
#                 "metric_data": [
#                     1.1993333333333336
#                 ],
#                 "metric_description": "Feature Metric to compute mean",
#                 "metric_name": "Mean",
#                 "variable_count": 1,
#                 "variable_dimensions": [
#                     0
#                 ],
#                 "variable_dtypes": [
#                     "FLOAT"
#                 ],
#                 "variable_names": [
#                     "mean"
#                 ],
#                 "variable_types": [
#                     "CONTINUOUS"
#                 ]
#             },
#             "Min": {
#                 "metadata": {},
#                 "metric_data": [
#                     0.1
#                 ],
#                 "metric_description": "Feature Metric to compute minimum value",
#                 "metric_name": "Min",
#                 "variable_count": 1,
#                 "variable_dimensions": [
#                     0
#                 ],
#                 "variable_dtypes": [
#                     "FLOAT"
#                 ],
#                 "variable_names": [
#                     "min"
#                 ],
#                 "variable_types": [
#                     "CONTINUOUS"
#                 ]
#             },
#             "Mode": {
#                 "metadata": {},
#                 "metric_data": [
#                     [
#                         "0.2"
#                     ]
#                 ],
#                 "metric_description": "Mode",
#                 "metric_name": "Mode",
#                 "variable_count": 1,
#                 "variable_dimensions": [
#                     1
#                 ],
#                 "variable_dtypes": [
#                     "STRING"
#                 ],
#                 "variable_names": [
#                     "mode"
#                 ],
#                 "variable_types": [
#                     "NOMINAL"
#                 ]
#             },
#             "Quartiles": {
#                 "metadata": {},
#                 "metric_data": [
#                     0.3,
#                     1.3,
#                     1.8
#                 ],
#                 "metric_description": "Feature Metric to compute Quartiles (Q1, Q2, Q3)",
#                 "metric_name": "Quartiles",
#                 "variable_count": 3,
#                 "variable_dimensions": [
#                     0,
#                     0,
#                     0
#                 ],
#                 "variable_dtypes": [
#                     "FLOAT",
#                     "FLOAT",
#                     "FLOAT"
#                 ],
#                 "variable_names": [
#                     "q1",
#                     "q2",
#                     "q3"
#                 ],
#                 "variable_types": [
#                     "CONTINUOUS",
#                     "CONTINUOUS",
#                     "CONTINUOUS"
#                 ]
#             },
#             "Range": {
#                 "metadata": {},
#                 "metric_data": [
#                     2.4
#                 ],
#                 "metric_description": "Feature Metric to compute range value",
#                 "metric_name": "Range",
#                 "variable_count": 1,
#                 "variable_dimensions": [
#                     0
#                 ],
#                 "variable_dtypes": [
#                     "FLOAT"
#                 ],
#                 "variable_names": [
#                     "range"
#                 ],
#                 "variable_types": [
#                     "CONTINUOUS"
#                 ]
#             },
#             "Skewness": {
#                 "metadata": {},
#                 "metric_data": [
#                     -0.10193420656560033
#                 ],
#                 "metric_description": "Feature Metric to compute Skewness",
#                 "metric_name": "Skewness",
#                 "variable_count": 1,
#                 "variable_dimensions": [
#                     0
#                 ],
#                 "variable_dtypes": [
#                     "FLOAT"
#                 ],
#                 "variable_names": [
#                     "skewness"
#                 ],
#                 "variable_types": [
#                     "CONTINUOUS"
#                 ]
#             },
#             "StandardDeviation": {
#                 "metadata": {},
#                 "metric_data": [
#                     0.7596926279021594
#                 ],
#                 "metric_description": "Feature Metric to compute Standard Deviation",
#                 "metric_name": "StandardDeviation",
#                 "variable_count": 1,
#                 "variable_dimensions": [
#                     0
#                 ],
#                 "variable_dtypes": [
#                     "FLOAT"
#                 ],
#                 "variable_names": [
#                     "standard_deviation"
#                 ],
#                 "variable_types": [
#                     "CONTINUOUS"
#                 ]
#             },
#             "Sum": {
#                 "metadata": {},
#                 "metric_data": [
#                     719.6000000000001
#                 ],
#                 "metric_description": "",
#                 "metric_name": "Sum",
#                 "variable_count": 1,
#                 "variable_dimensions": [
#                     0
#                 ],
#                 "variable_dtypes": [
#                     "FLOAT"
#                 ],
#                 "variable_names": [
#                     "sum"
#                 ],
#                 "variable_types": [
#                     "CONTINUOUS"
#                 ]
#             },
#             "TypeMetric": {
#                 "metadata": {},
#                 "metric_data": [
#                     0,
#                     0,
#                     600,
#                     0
#                 ],
#                 "metric_description": "Feature Metric to compute count of data types for feature values",
#                 "metric_name": "TypeMetric",
#                 "variable_count": 4,
#                 "variable_dimensions": [
#                     0,
#                     0,
#                     0,
#                     0
#                 ],
#                 "variable_dtypes": [
#                     "INTEGER",
#                     "INTEGER",
#                     "INTEGER",
#                     "INTEGER"
#                 ],
#                 "variable_names": [
#                     "string_type_count",
#                     "integral_type_count",
#                     "fractional_type_count",
#                     "boolean_type_count"
#                 ],
#                 "variable_types": [
#                     "DISCRETE",
#                     "DISCRETE",
#                     "DISCRETE",
#                     "DISCRETE"
#                 ]
#             },
#             "Variance": {
#                 "metadata": {},
#                 "metric_data": [
#                     0.5771328888888888
#                 ],
#                 "metric_description": "Feature Metric to compute Variance",
#                 "metric_name": "Variance",
#                 "variable_count": 1,
#                 "variable_dimensions": [
#                     0
#                 ],
#                 "variable_dtypes": [
#                     "FLOAT"
#                 ],
#                 "variable_names": [
#                     "variance"
#                 ],
#                 "variable_types": [
#                     "CONTINUOUS"
#                 ]
#             }
#         },
#         "sepal length (cm)": {
#             "Count": {
#                 "metadata": {},
#                 "metric_data": [
#                     600.0,
#                     0.0,
#                     0.0
#                 ],
#                 "metric_description": "Feature metric that returns total count, missing count and missing count percentage",
#                 "metric_name": "Count",
#                 "variable_count": 3,
#                 "variable_dimensions": [
#                     0,
#                     0,
#                     0
#                 ],
#                 "variable_dtypes": [
#                     "INTEGER",
#                     "INTEGER",
#                     "FLOAT"
#                 ],
#                 "variable_names": [
#                     "total_count",
#                     "missing_count",
#                     "missing_count_percentage"
#                 ],
#                 "variable_types": [
#                     "CONTINUOUS",
#                     "CONTINUOUS",
#                     "CONTINUOUS"
#                 ]
#             },
#             "DistinctCount": {
#                 "metadata": {},
#                 "metric_data": [
#                     35
#                 ],
#                 "metric_description": "Approximate Distinct Count",
#                 "metric_name": "DistinctCount",
#                 "variable_count": 1,
#                 "variable_dimensions": [
#                     0
#                 ],
#                 "variable_dtypes": [
#                     "INTEGER"
#                 ],
#                 "variable_names": [
#                     "distinct_count"
#                 ],
#                 "variable_types": [
#                     "CONTINUOUS"
#                 ]
#             },
#             "DuplicateCount": {
#                 "metadata": {},
#                 "metric_data": [
#                     565,
#                     94.16666666666667
#                 ],
#                 "metric_description": "Feature Metric to compute duplicate count and duplicate count percentage",
#                 "metric_name": "DuplicateCount",
#                 "variable_count": 2,
#                 "variable_dimensions": [
#                     0,
#                     0
#                 ],
#                 "variable_dtypes": [
#                     "INTEGER",
#                     "FLOAT"
#                 ],
#                 "variable_names": [
#                     "count",
#                     "percentage"
#                 ],
#                 "variable_types": [
#                     "CONTINUOUS",
#                     "CONTINUOUS"
#                 ]
#             },
#             "IQR": {
#                 "metadata": {},
#                 "metric_data": [
#                     1.3000000000000007
#                 ],
#                 "metric_description": "Compute the interquartile range of the data. Interquartile range (IQR) is the difference between the 75th and 25th percentile of the data. It is a measure of the dispersion similar to standard deviation or variance, but is much more robust against outliers",
#                 "metric_name": "IQR",
#                 "variable_count": 1,
#                 "variable_dimensions": [
#                     0
#                 ],
#                 "variable_dtypes": [
#                     "FLOAT"
#                 ],
#                 "variable_names": [
#                     "iqr"
#                 ],
#                 "variable_types": [
#                     "CONTINUOUS"
#                 ]
#             },
#             "IsConstantFeature": {
#                 "metadata": {},
#                 "metric_data": [
#                     false
#                 ],
#                 "metric_description": "Feature Metric to compute if all values are same",
#                 "metric_name": "IsConstantFeature",
#                 "variable_count": 1,
#                 "variable_dimensions": [
#                     0
#                 ],
#                 "variable_dtypes": [
#                     "BOOLEAN"
#                 ],
#                 "variable_names": [
#                     "is_constant"
#                 ],
#                 "variable_types": [
#                     "BINARY"
#                 ]
#             },
#             "IsQuasiConstantFeature": {
#                 "metadata": {},
#                 "metric_data": [
#                     false
#                 ],
#                 "metric_description": "Feature Metric to compute if all values are almost same",
#                 "metric_name": "IsQuasiConstantFeature",
#                 "variable_count": 1,
#                 "variable_dimensions": [
#                     0
#                 ],
#                 "variable_dtypes": [
#                     "BOOLEAN"
#                 ],
#                 "variable_names": [
#                     "is_quasi_constant"
#                 ],
#                 "variable_types": [
#                     "BINARY"
#                 ]
#             },
#             "Kurtosis": {
#                 "metadata": {},
#                 "metric_data": [
#                     -0.5735679489249765
#                 ],
#                 "metric_description": "Feature Metric to compute Kurtosis",
#                 "metric_name": "Kurtosis",
#                 "variable_count": 1,
#                 "variable_dimensions": [
#                     0
#                 ],
#                 "variable_dtypes": [
#                     "FLOAT"
#                 ],
#                 "variable_names": [
#                     "kurtosis"
#                 ],
#                 "variable_types": [
#                     "CONTINUOUS"
#                 ]
#             },
#             "Max": {
#                 "metadata": {},
#                 "metric_data": [
#                     7.9
#                 ],
#                 "metric_description": "Feature Metric to compute maximum value",
#                 "metric_name": "Max",
#                 "variable_count": 1,
#                 "variable_dimensions": [
#                     0
#                 ],
#                 "variable_dtypes": [
#                     "FLOAT"
#                 ],
#                 "variable_names": [
#                     "max"
#                 ],
#                 "variable_types": [
#                     "CONTINUOUS"
#                 ]
#             },
#             "Mean": {
#                 "metadata": {},
#                 "metric_data": [
#                     5.843333333333334
#                 ],
#                 "metric_description": "Feature Metric to compute mean",
#                 "metric_name": "Mean",
#                 "variable_count": 1,
#                 "variable_dimensions": [
#                     0
#                 ],
#                 "variable_dtypes": [
#                     "FLOAT"
#                 ],
#                 "variable_names": [
#                     "mean"
#                 ],
#                 "variable_types": [
#                     "CONTINUOUS"
#                 ]
#             },
#             "Min": {
#                 "metadata": {},
#                 "metric_data": [
#                     4.3
#                 ],
#                 "metric_description": "Feature Metric to compute minimum value",
#                 "metric_name": "Min",
#                 "variable_count": 1,
#                 "variable_dimensions": [
#                     0
#                 ],
#                 "variable_dtypes": [
#                     "FLOAT"
#                 ],
#                 "variable_names": [
#                     "min"
#                 ],
#                 "variable_types": [
#                     "CONTINUOUS"
#                 ]
#             },
#             "Mode": {
#                 "metadata": {},
#                 "metric_data": [
#                     [
#                         "5.0"
#                     ]
#                 ],
#                 "metric_description": "Mode",
#                 "metric_name": "Mode",
#                 "variable_count": 1,
#                 "variable_dimensions": [
#                     1
#                 ],
#                 "variable_dtypes": [
#                     "STRING"
#                 ],
#                 "variable_names": [
#                     "mode"
#                 ],
#                 "variable_types": [
#                     "NOMINAL"
#                 ]
#             },
#             "Quartiles": {
#                 "metadata": {},
#                 "metric_data": [
#                     5.1,
#                     5.8,
#                     6.4
#                 ],
#                 "metric_description": "Feature Metric to compute Quartiles (Q1, Q2, Q3)",
#                 "metric_name": "Quartiles",
#                 "variable_count": 3,
#                 "variable_dimensions": [
#                     0,
#                     0,
#                     0
#                 ],
#                 "variable_dtypes": [
#                     "FLOAT",
#                     "FLOAT",
#                     "FLOAT"
#                 ],
#                 "variable_names": [
#                     "q1",
#                     "q2",
#                     "q3"
#                 ],
#                 "variable_types": [
#                     "CONTINUOUS",
#                     "CONTINUOUS",
#                     "CONTINUOUS"
#                 ]
#             },
#             "Range": {
#                 "metadata": {},
#                 "metric_data": [
#                     3.6000000000000005
#                 ],
#                 "metric_description": "Feature Metric to compute range value",
#                 "metric_name": "Range",
#                 "variable_count": 1,
#                 "variable_dimensions": [
#                     0
#                 ],
#                 "variable_dtypes": [
#                     "FLOAT"
#                 ],
#                 "variable_names": [
#                     "range"
#                 ],
#                 "variable_types": [
#                     "CONTINUOUS"
#                 ]
#             },
#             "Skewness": {
#                 "metadata": {},
#                 "metric_data": [
#                     0.311753058502296
#                 ],
#                 "metric_description": "Feature Metric to compute Skewness",
#                 "metric_name": "Skewness",
#                 "variable_count": 1,
#                 "variable_dimensions": [
#                     0
#                 ],
#                 "variable_dtypes": [
#                     "FLOAT"
#                 ],
#                 "variable_names": [
#                     "skewness"
#                 ],
#                 "variable_types": [
#                     "CONTINUOUS"
#                 ]
#             },
#             "StandardDeviation": {
#                 "metadata": {},
#                 "metric_data": [
#                     0.8253012917851409
#                 ],
#                 "metric_description": "Feature Metric to compute Standard Deviation",
#                 "metric_name": "StandardDeviation",
#                 "variable_count": 1,
#                 "variable_dimensions": [
#                     0
#                 ],
#                 "variable_dtypes": [
#                     "FLOAT"
#                 ],
#                 "variable_names": [
#                     "standard_deviation"
#                 ],
#                 "variable_types": [
#                     "CONTINUOUS"
#                 ]
#             },
#             "Sum": {
#                 "metadata": {},
#                 "metric_data": [
#                     3506.0
#                 ],
#                 "metric_description": "",
#                 "metric_name": "Sum",
#                 "variable_count": 1,
#                 "variable_dimensions": [
#                     0
#                 ],
#                 "variable_dtypes": [
#                     "FLOAT"
#                 ],
#                 "variable_names": [
#                     "sum"
#                 ],
#                 "variable_types": [
#                     "CONTINUOUS"
#                 ]
#             },
#             "TypeMetric": {
#                 "metadata": {},
#                 "metric_data": [
#                     0,
#                     0,
#                     600,
#                     0
#                 ],
#                 "metric_description": "Feature Metric to compute count of data types for feature values",
#                 "metric_name": "TypeMetric",
#                 "variable_count": 4,
#                 "variable_dimensions": [
#                     0,
#                     0,
#                     0,
#                     0
#                 ],
#                 "variable_dtypes": [
#                     "INTEGER",
#                     "INTEGER",
#                     "INTEGER",
#                     "INTEGER"
#                 ],
#                 "variable_names": [
#                     "string_type_count",
#                     "integral_type_count",
#                     "fractional_type_count",
#                     "boolean_type_count"
#                 ],
#                 "variable_types": [
#                     "DISCRETE",
#                     "DISCRETE",
#                     "DISCRETE",
#                     "DISCRETE"
#                 ]
#             },
#             "Variance": {
#                 "metadata": {},
#                 "metric_data": [
#                     0.6811222222222223
#                 ],
#                 "metric_description": "Feature Metric to compute Variance",
#                 "metric_name": "Variance",
#                 "variable_count": 1,
#                 "variable_dimensions": [
#                     0
#                 ],
#                 "variable_dtypes": [
#                     "FLOAT"
#                 ],
#                 "variable_names": [
#                     "variance"
#                 ],
#                 "variable_types": [
#                     "CONTINUOUS"
#                 ]
#             }
#         },
#         "sepal width (cm)": {
#             "Count": {
#                 "metadata": {},
#                 "metric_data": [
#                     600.0,
#                     0.0,
#                     0.0
#                 ],
#                 "metric_description": "Feature metric that returns total count, missing count and missing count percentage",
#                 "metric_name": "Count",
#                 "variable_count": 3,
#                 "variable_dimensions": [
#                     0,
#                     0,
#                     0
#                 ],
#                 "variable_dtypes": [
#                     "INTEGER",
#                     "INTEGER",
#                     "FLOAT"
#                 ],
#                 "variable_names": [
#                     "total_count",
#                     "missing_count",
#                     "missing_count_percentage"
#                 ],
#                 "variable_types": [
#                     "CONTINUOUS",
#                     "CONTINUOUS",
#                     "CONTINUOUS"
#                 ]
#             },
#             "DistinctCount": {
#                 "metadata": {},
#                 "metric_data": [
#                     23
#                 ],
#                 "metric_description": "Approximate Distinct Count",
#                 "metric_name": "DistinctCount",
#                 "variable_count": 1,
#                 "variable_dimensions": [
#                     0
#                 ],
#                 "variable_dtypes": [
#                     "INTEGER"
#                 ],
#                 "variable_names": [
#                     "distinct_count"
#                 ],
#                 "variable_types": [
#                     "CONTINUOUS"
#                 ]
#             },
#             "DuplicateCount": {
#                 "metadata": {},
#                 "metric_data": [
#                     577,
#                     96.16666666666667
#                 ],
#                 "metric_description": "Feature Metric to compute duplicate count and duplicate count percentage",
#                 "metric_name": "DuplicateCount",
#                 "variable_count": 2,
#                 "variable_dimensions": [
#                     0,
#                     0
#                 ],
#                 "variable_dtypes": [
#                     "INTEGER",
#                     "FLOAT"
#                 ],
#                 "variable_names": [
#                     "count",
#                     "percentage"
#                 ],
#                 "variable_types": [
#                     "CONTINUOUS",
#                     "CONTINUOUS"
#                 ]
#             },
#             "IQR": {
#                 "metadata": {},
#                 "metric_data": [
#                     0.5
#                 ],
#                 "metric_description": "Compute the interquartile range of the data. Interquartile range (IQR) is the difference between the 75th and 25th percentile of the data. It is a measure of the dispersion similar to standard deviation or variance, but is much more robust against outliers",
#                 "metric_name": "IQR",
#                 "variable_count": 1,
#                 "variable_dimensions": [
#                     0
#                 ],
#                 "variable_dtypes": [
#                     "FLOAT"
#                 ],
#                 "variable_names": [
#                     "iqr"
#                 ],
#                 "variable_types": [
#                     "CONTINUOUS"
#                 ]
#             },
#             "IsConstantFeature": {
#                 "metadata": {},
#                 "metric_data": [
#                     false
#                 ],
#                 "metric_description": "Feature Metric to compute if all values are same",
#                 "metric_name": "IsConstantFeature",
#                 "variable_count": 1,
#                 "variable_dimensions": [
#                     0
#                 ],
#                 "variable_dtypes": [
#                     "BOOLEAN"
#                 ],
#                 "variable_names": [
#                     "is_constant"
#                 ],
#                 "variable_types": [
#                     "BINARY"
#                 ]
#             },
#             "IsQuasiConstantFeature": {
#                 "metadata": {},
#                 "metric_data": [
#                     false
#                 ],
#                 "metric_description": "Feature Metric to compute if all values are almost same",
#                 "metric_name": "IsQuasiConstantFeature",
#                 "variable_count": 1,
#                 "variable_dimensions": [
#                     0
#                 ],
#                 "variable_dtypes": [
#                     "BOOLEAN"
#                 ],
#                 "variable_names": [
#                     "is_quasi_constant"
#                 ],
#                 "variable_types": [
#                     "BINARY"
#                 ]
#             },
#             "Kurtosis": {
#                 "metadata": {},
#                 "metric_data": [
#                     0.18097631752246723
#                 ],
#                 "metric_description": "Feature Metric to compute Kurtosis",
#                 "metric_name": "Kurtosis",
#                 "variable_count": 1,
#                 "variable_dimensions": [
#                     0
#                 ],
#                 "variable_dtypes": [
#                     "FLOAT"
#                 ],
#                 "variable_names": [
#                     "kurtosis"
#                 ],
#                 "variable_types": [
#                     "CONTINUOUS"
#                 ]
#             },
#             "Max": {
#                 "metadata": {},
#                 "metric_data": [
#                     4.4
#                 ],
#                 "metric_description": "Feature Metric to compute maximum value",
#                 "metric_name": "Max",
#                 "variable_count": 1,
#                 "variable_dimensions": [
#                     0
#                 ],
#                 "variable_dtypes": [
#                     "FLOAT"
#                 ],
#                 "variable_names": [
#                     "max"
#                 ],
#                 "variable_types": [
#                     "CONTINUOUS"
#                 ]
#             },
#             "Mean": {
#                 "metadata": {},
#                 "metric_data": [
#                     3.0573333333333337
#                 ],
#                 "metric_description": "Feature Metric to compute mean",
#                 "metric_name": "Mean",
#                 "variable_count": 1,
#                 "variable_dimensions": [
#                     0
#                 ],
#                 "variable_dtypes": [
#                     "FLOAT"
#                 ],
#                 "variable_names": [
#                     "mean"
#                 ],
#                 "variable_types": [
#                     "CONTINUOUS"
#                 ]
#             },
#             "Min": {
#                 "metadata": {},
#                 "metric_data": [
#                     2.0
#                 ],
#                 "metric_description": "Feature Metric to compute minimum value",
#                 "metric_name": "Min",
#                 "variable_count": 1,
#                 "variable_dimensions": [
#                     0
#                 ],
#                 "variable_dtypes": [
#                     "FLOAT"
#                 ],
#                 "variable_names": [
#                     "min"
#                 ],
#                 "variable_types": [
#                     "CONTINUOUS"
#                 ]
#             },
#             "Mode": {
#                 "metadata": {},
#                 "metric_data": [
#                     [
#                         "3.0"
#                     ]
#                 ],
#                 "metric_description": "Mode",
#                 "metric_name": "Mode",
#                 "variable_count": 1,
#                 "variable_dimensions": [
#                     1
#                 ],
#                 "variable_dtypes": [
#                     "STRING"
#                 ],
#                 "variable_names": [
#                     "mode"
#                 ],
#                 "variable_types": [
#                     "NOMINAL"
#                 ]
#             },
#             "Quartiles": {
#                 "metadata": {},
#                 "metric_data": [
#                     2.8,
#                     3.0,
#                     3.3
#                 ],
#                 "metric_description": "Feature Metric to compute Quartiles (Q1, Q2, Q3)",
#                 "metric_name": "Quartiles",
#                 "variable_count": 3,
#                 "variable_dimensions": [
#                     0,
#                     0,
#                     0
#                 ],
#                 "variable_dtypes": [
#                     "FLOAT",
#                     "FLOAT",
#                     "FLOAT"
#                 ],
#                 "variable_names": [
#                     "q1",
#                     "q2",
#                     "q3"
#                 ],
#                 "variable_types": [
#                     "CONTINUOUS",
#                     "CONTINUOUS",
#                     "CONTINUOUS"
#                 ]
#             },
#             "Range": {
#                 "metadata": {},
#                 "metric_data": [
#                     2.4000000000000004
#                 ],
#                 "metric_description": "Feature Metric to compute range value",
#                 "metric_name": "Range",
#                 "variable_count": 1,
#                 "variable_dimensions": [
#                     0
#                 ],
#                 "variable_dtypes": [
#                     "FLOAT"
#                 ],
#                 "variable_names": [
#                     "range"
#                 ],
#                 "variable_types": [
#                     "CONTINUOUS"
#                 ]
#             },
#             "Skewness": {
#                 "metadata": {},
#                 "metric_data": [
#                     0.31576710633893473
#                 ],
#                 "metric_description": "Feature Metric to compute Skewness",
#                 "metric_name": "Skewness",
#                 "variable_count": 1,
#                 "variable_dimensions": [
#                     0
#                 ],
#                 "variable_dtypes": [
#                     "FLOAT"
#                 ],
#                 "variable_names": [
#                     "skewness"
#                 ],
#                 "variable_types": [
#                     "CONTINUOUS"
#                 ]
#             },
#             "StandardDeviation": {
#                 "metadata": {},
#                 "metric_data": [
#                     0.4344109677354946
#                 ],
#                 "metric_description": "Feature Metric to compute Standard Deviation",
#                 "metric_name": "StandardDeviation",
#                 "variable_count": 1,
#                 "variable_dimensions": [
#                     0
#                 ],
#                 "variable_dtypes": [
#                     "FLOAT"
#                 ],
#                 "variable_names": [
#                     "standard_deviation"
#                 ],
#                 "variable_types": [
#                     "CONTINUOUS"
#                 ]
#             },
#             "Sum": {
#                 "metadata": {},
#                 "metric_data": [
#                     1834.4
#                 ],
#                 "metric_description": "",
#                 "metric_name": "Sum",
#                 "variable_count": 1,
#                 "variable_dimensions": [
#                     0
#                 ],
#                 "variable_dtypes": [
#                     "FLOAT"
#                 ],
#                 "variable_names": [
#                     "sum"
#                 ],
#                 "variable_types": [
#                     "CONTINUOUS"
#                 ]
#             },
#             "TypeMetric": {
#                 "metadata": {},
#                 "metric_data": [
#                     0,
#                     0,
#                     600,
#                     0
#                 ],
#                 "metric_description": "Feature Metric to compute count of data types for feature values",
#                 "metric_name": "TypeMetric",
#                 "variable_count": 4,
#                 "variable_dimensions": [
#                     0,
#                     0,
#                     0,
#                     0
#                 ],
#                 "variable_dtypes": [
#                     "INTEGER",
#                     "INTEGER",
#                     "INTEGER",
#                     "INTEGER"
#                 ],
#                 "variable_names": [
#                     "string_type_count",
#                     "integral_type_count",
#                     "fractional_type_count",
#                     "boolean_type_count"
#                 ],
#                 "variable_types": [
#                     "DISCRETE",
#                     "DISCRETE",
#                     "DISCRETE",
#                     "DISCRETE"
#                 ]
#             },
#             "Variance": {
#                 "metadata": {},
#                 "metric_data": [
#                     0.1887128888888889
#                 ],
#                 "metric_description": "Feature Metric to compute Variance",
#                 "metric_name": "Variance",
#                 "variable_count": 1,
#                 "variable_dimensions": [
#                     0
#                 ],
#                 "variable_dtypes": [
#                     "FLOAT"
#                 ],
#                 "variable_names": [
#                     "variance"
#                 ],
#                 "variable_types": [
#                     "CONTINUOUS"
#                 ]
#             }
#         }
#     }
# }

# %%
pd.json_normalize(dataset_metrics).T.dropna()
# Out:
#                                                                                      0
# feature_metrics.sepal length (cm).Skewness.metr...                            Skewness
# feature_metrics.sepal length (cm).Skewness.metr...  Feature Metric to compute Skewness
# feature_metrics.sepal length (cm).Skewness.vari...                                   1
# feature_metrics.sepal length (cm).Skewness.vari...                          [skewness]
# feature_metrics.sepal length (cm).Skewness.vari...                        [CONTINUOUS]
# ...                                                                                ...
# feature_metrics.petal width (cm).Kurtosis.varia...                          [kurtosis]
# feature_metrics.petal width (cm).Kurtosis.varia...                        [CONTINUOUS]
# feature_metrics.petal width (cm).Kurtosis.varia...                             [FLOAT]
# feature_metrics.petal width (cm).Kurtosis.varia...                                 [0]
# feature_metrics.petal width (cm).Kurtosis.metri...               [-1.3360674052315529]
#
# [576 rows x 1 columns]
